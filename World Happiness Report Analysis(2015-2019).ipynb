# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rep_2015 = pd.read_csv('C:\\Users\\sukra\\Downloads\\2015 - 2015.csv.csv')
rep_2016 = pd.read_csv('C:\\Users\\sukra\\Downloads\\2015 - 2016.csv')
rep_2017 = pd.read_csv('C:\\Users\\sukra\\Downloads\\World Happiness Report - 2017.csv')
rep_2018 = pd.read_csv('C:\\Users\\sukra\\Downloads\\World Happiness Report - 2018.csv')
rep_2019 = pd.read_csv('C:\\Users\\sukra\\Downloads\\World Happiness Report - 2019.csv')

# %% [markdown]
# ## Basic exploration for every year.

# %% [markdown]
# Year 2015

# %%
rep_2015.shape
# Out:
# (158, 12)

# %%
rep_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Trust (Government Corruption)  158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
rep_2015.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Dystopia Residual                0
# dtype: int64

# %%
rep_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Generosity  \
# 0                   0.94143  0.66557     0.29678
# 1                   0.94784  0.62877     0.43630
# 2                   0.87464  0.64938     0.34139
# 3                   0.88521  0.66973     0.34699
# ...

# %%
rep_2015.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Year 2016

# %%
rep_2016.shape
# Out:
# (157, 14)

# %%
rep_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Upper Confidence Interval      157 non-null    float64
#  5   Lower Confidence Interval      157 non-null    float64
#  6   Standard Error                 157 non-null    float64
#  7   Economy (GDP per Capita)       157 non-null    float64
#  8   Family                         157 non-null    float64
#  9   Health (Life Expectancy)       157 non-null    float64
#  10  Freedom                        157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
rep_2016.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Upper Confidence Interval        0
# Lower Confidence Interval        0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Dystopia Residual                0
# dtype: int64

# %%
rep_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Upper Confidence Interval  Lower Confidence Interval  Standard Error  \
# 0                      7.592                      7.460           0.132
# 1                      7.590                      7.428           0.162
# 2                      7.669                      7.333           0.336
# 3                      7.575                      7.421           0.154
# 4                      7.475                      7.351           0.124
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
rep_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Upper Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.481975
# std         45.466030         1.141674                   1.136493
# min          1.000000         2.905000                   3.078000
# 25%         40.000000         4.404000                   4.465000
# 50%         79.000000         5.314000                   5.419000
# 75%        118.000000         6.269000                   6.434000
# max        157.000000         7.526000                   7.669000
#
#        Lower Confidence Interval  Standard Error  Economy (GDP per Capita)  \
# count                 157.000000       157.00000                157.000000
# mean                    5.282395         0.19958                  0.953880
# std                     1.148043         0.07459                  0.412595
# ...

# %% [markdown]
# Year 2017

# %%
rep_2017.shape
# Out:
# (155, 13)

# %%
rep_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        155 non-null    object
#  1   Happiness Rank                 155 non-null    int64
#  2   Happiness Score                155 non-null    float64
#  3   Whisker.high                   155 non-null    float64
#  4   Whisker.low                    155 non-null    float64
#  5   Standard Error                 155 non-null    float64
#  6   Economy (GDP per Capita)       155 non-null    float64
#  7   Family                         155 non-null    float64
#  8   Health (Life Expectancy)       155 non-null    float64
#  9   Freedom                        155 non-null    float64
#  10  Generosity                     155 non-null    float64
#  11  Trust (Government Corruption)  155 non-null    float64
# ...

# %%
rep_2017.isna().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# Dystopia.Residual                0
# dtype: int64

# %%
rep_2017.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Standard Error  Economy (GDP per Capita)    Family  \
# 0        0.114889                  1.616463  1.533524
# 1        0.119456                  1.482383  1.551122
# 2        0.236061                  1.480633  1.610574
# 3        0.135545                  1.564980  1.516912
# 4        0.117084                  1.443572  1.540247
#
#    Health (Life Expectancy)   Freedom  Generosity  \
# 0                  0.796667  0.635423    0.362012
# 1                  0.792566  0.626007    0.355280
# ...

# %%
rep_2017.describe()
# Out:
#        Happiness Rank  Happiness Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      155.000000                155.000000  155.000000
# mean         0.196613                  0.984718    1.188898
# std          0.075706                  0.420793    0.287263
# min          0.092557                  0.000000    0.000000
# 25%          0.151977                  0.663371    1.042635
# ...

# %% [markdown]
# Year 2018

# %%
rep_2018.shape
# Out:
# (156, 9)

# %%
rep_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country or region              156 non-null    object
#  1   Happiness Rank                 156 non-null    int64
#  2   Happiness Score                156 non-null    float64
#  3   Economy (GDP per Capita)       156 non-null    float64
#  4   Family                         156 non-null    float64
#  5   Health (Life Expectancy)       156 non-null    float64
#  6   Freedom                        156 non-null    float64
#  7   Generosity                     156 non-null    float64
#  8   Trust (Government Corruption)  155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
rep_2018.isna().sum()
# Out:
# Country or region                0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    1
# dtype: int64

# %%
rep_2018.head()
# Out:
#   Country or region  Happiness Rank  Happiness Score  \
# 0           Finland               1            7.632
# 1            Norway               2            7.594
# 2           Denmark               3            7.555
# 3           Iceland               4            7.495
# 4       Switzerland               5            7.487
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom   \
# 0                     1.305   1.592                     0.874     0.681
# 1                     1.456   1.582                     0.861     0.686
# 2                     1.351   1.590                     0.868     0.683
# 3                     1.343   1.644                     0.914     0.677
# 4                     1.420   1.549                     0.927     0.660
#
#    Generosity  Trust (Government Corruption)
# 0       0.202                          0.393
# 1       0.286                          0.340
# 2       0.284                          0.408
# ...

# %%
rep_2018.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      156.000000       156.000000                156.000000  156.000000
# mean        78.500000         5.375917                  0.891449    1.213237
# std         45.177428         1.119506                  0.391921    0.302372
# min          1.000000         2.905000                  0.000000    0.000000
# 25%         39.750000         4.453750                  0.616250    1.066750
# 50%         78.500000         5.378000                  0.949500    1.255000
# 75%        117.250000         6.168500                  1.197750    1.463000
# max        156.000000         7.632000                  2.096000    1.644000
#
#        Health (Life Expectancy)    Freedom   Generosity  \
# count                156.000000  156.000000  156.000000
# mean                   0.597346    0.454506    0.181006
# std                    0.247579    0.162424    0.098471
# ...

# %% [markdown]
# Year 2019

# %%
rep_2019.shape
# Out:
# (156, 9)

# %%
rep_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country or region              156 non-null    object
#  1   Happiness Rank                 156 non-null    int64
#  2   Happiness Score                156 non-null    float64
#  3   Economy (GDP per Capita)       156 non-null    float64
#  4   Family                         156 non-null    float64
#  5   Health (Life Expectancy)       156 non-null    float64
#  6   Freedom                        156 non-null    float64
#  7   Generosity                     156 non-null    float64
#  8   Trust (Government Corruption)  156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
rep_2019.isna().sum()
# Out:
# Country or region                0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Generosity                       0
# Trust (Government Corruption)    0
# dtype: int64

# %%
rep_2019.head()
# Out:
#   Country or region  Happiness Rank  Happiness Score  \
# 0           Finland               1            7.769
# 1           Denmark               2            7.600
# 2            Norway               3            7.554
# 3           Iceland               4            7.494
# 4       Netherlands               5            7.488
#
#    Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                     1.340   1.587                     0.986    0.596
# 1                     1.383   1.573                     0.996    0.592
# 2                     1.488   1.582                     1.028    0.603
# 3                     1.380   1.624                     1.026    0.591
# 4                     1.396   1.522                     0.999    0.557
#
#    Generosity  Trust (Government Corruption)
# 0       0.153                          0.393
# 1       0.252                          0.410
# 2       0.271                          0.341
# ...

# %%
rep_2019.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      156.000000       156.000000                156.000000  156.000000
# mean        78.500000         5.407096                  0.905147    1.208814
# std         45.177428         1.113120                  0.398389    0.299191
# min          1.000000         2.853000                  0.000000    0.000000
# 25%         39.750000         4.544500                  0.602750    1.055750
# 50%         78.500000         5.379500                  0.960000    1.271500
# 75%        117.250000         6.184500                  1.232500    1.452500
# max        156.000000         7.769000                  1.684000    1.624000
#
#        Health (Life Expectancy)     Freedom  Generosity  \
# count                156.000000  156.000000  156.000000
# mean                   0.725244    0.392571    0.184846
# std                    0.242124    0.143289    0.095254
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# Standardizing Columns

# %%
rep_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Generosity',
#        'Trust (Government Corruption)', 'Dystopia Residual'],
#       dtype='object')

# %%
rep_2015.rename(columns = {'Happiness Rank':'Rank', 'Happiness Score':'Score', 'Economy (GDP per Capita)':'GDP',
       'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Corruption'}, inplace = True)

# %%
rep_2015['Year'] = 2015
rep_2015
# Out:
#          Country                           Region  Rank  Score  \
# 0    Switzerland                   Western Europe     1  7.587
# 1        Iceland                   Western Europe     2  7.561
# 2        Denmark                   Western Europe     3  7.527
# 3         Norway                   Western Europe     4  7.522
# 4         Canada                    North America     5  7.427
# ..           ...                              ...   ...    ...
# 153       Rwanda               Sub-Saharan Africa   154  3.465
# 154        Benin               Sub-Saharan Africa   155  3.340
# 155        Syria  Middle East and Northern Africa   156  3.006
# 156      Burundi               Sub-Saharan Africa   157  2.905
# 157         Togo               Sub-Saharan Africa   158  2.839
#
#      Standard Error      GDP   Family   Health  Freedom  Generosity  \
# 0           0.03411  1.39651  1.34951  0.94143  0.66557     0.29678
# 1           0.04884  1.30232  1.40223  0.94784  0.62877     0.43630
# ...

# %%
rep_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Upper Confidence Interval', 'Lower Confidence Interval',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Generosity',
#        'Trust (Government Corruption)', 'Dystopia Residual'],
#       dtype='object')

# %%
rep_2016.rename(columns = {'Happiness Rank':'Rank', 'Happiness Score':'Score', 'Economy (GDP per Capita)':'GDP',
       'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Corruption'}, inplace = True)
rep_2016
# Out:
#          Country                           Region  Rank  Score  \
# 0        Denmark                   Western Europe     1  7.526
# 1    Switzerland                   Western Europe     2  7.509
# 2        Iceland                   Western Europe     3  7.501
# 3         Norway                   Western Europe     4  7.498
# 4        Finland                   Western Europe     5  7.413
# ..           ...                              ...   ...    ...
# 152        Benin               Sub-Saharan Africa   153  3.484
# 153  Afghanistan                    Southern Asia   154  3.360
# 154         Togo               Sub-Saharan Africa   155  3.303
# 155        Syria  Middle East and Northern Africa   156  3.069
# 156      Burundi               Sub-Saharan Africa   157  2.905
#
#      Upper Confidence Interval  Lower Confidence Interval  Standard Error  \
# 0                        7.592                      7.460           0.132
# ...

# %%
rep_2016['Year']= 2016

# %%
rep_2017.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score', 'Whisker.high',
#        'Whisker.low', 'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Generosity',
#        'Trust (Government Corruption)', 'Dystopia.Residual'],
#       dtype='object')

# %%
rep_2017.rename(columns = {'Happiness Rank':'Rank', 'Happiness Score':'Score', 'Economy (GDP per Capita)':'GDP',
       'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Corruption'}, inplace = True)
rep_2017
# Out:
#                       Country  Rank  Score  Whisker.high  Whisker.low  \
# 0                      Norway     1  7.537      7.594445     7.479556
# 1                     Denmark     2  7.522      7.581728     7.462272
# 2                     Iceland     3  7.504      7.622030     7.385970
# 3                 Switzerland     4  7.494      7.561772     7.426227
# 4                     Finland     5  7.469      7.527542     7.410458
# ..                        ...   ...    ...           ...          ...
# 150                    Rwanda   151  3.471      3.543030     3.398970
# 151                     Syria   152  3.462      3.663669     3.260331
# 152                  Tanzania   153  3.349      3.461430     3.236570
# 153                   Burundi   154  2.905      3.074690     2.735310
# 154  Central African Republic   155  2.693      2.864884     2.521116
#
#      Standard Error       GDP    Family    Health   Freedom  Generosity  \
# ...

# %%
rep_2017['Year']=2017

# %%
rep_2018.columns
# Out:
# Index(['Country or region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom ', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
rep_2018.rename(columns = {'Country or region':'Country','Happiness Rank':'Rank', 'Happiness Score':'Score', 'Economy (GDP per Capita)':'GDP',
       'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Corruption'}, inplace = True)
rep_2018
# Out:
#                       Country  Rank  Score    GDP  Family  Health  Freedom   \
# 0                     Finland     1  7.632  1.305   1.592   0.874     0.681
# 1                      Norway     2  7.594  1.456   1.582   0.861     0.686
# 2                     Denmark     3  7.555  1.351   1.590   0.868     0.683
# 3                     Iceland     4  7.495  1.343   1.644   0.914     0.677
# 4                 Switzerland     5  7.487  1.420   1.549   0.927     0.660
# ..                        ...   ...    ...    ...     ...     ...       ...
# 151                     Yemen   152  3.355  0.442   1.073   0.343     0.244
# 152                  Tanzania   153  3.303  0.455   0.991   0.381     0.481
# 153               South Sudan   154  3.254  0.337   0.608   0.177     0.112
# 154  Central African Republic   155  3.083  0.024   0.000   0.010     0.305
# 155                   Burundi   156  2.905  0.091   0.627   0.145     0.065
#
#      Generosity  Corruption
# ...

# %%
rep_2018['Year']=2018

# %%
rep_2019.columns
# Out:
# Index(['Country or region', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Generosity', 'Trust (Government Corruption)'],
#       dtype='object')

# %%
rep_2019.rename(columns = {'Country or region':'Country', 'Happiness Rank':'Rank', 'Happiness Score':'Score', 'Economy (GDP per Capita)':'GDP',
       'Health (Life Expectancy)':'Health','Trust (Government Corruption)':'Corruption'}, inplace = True)
rep_2019
# Out:
#                       Country  Rank  Score    GDP  Family  Health  Freedom  \
# 0                     Finland     1  7.769  1.340   1.587   0.986    0.596
# 1                     Denmark     2  7.600  1.383   1.573   0.996    0.592
# 2                      Norway     3  7.554  1.488   1.582   1.028    0.603
# 3                     Iceland     4  7.494  1.380   1.624   1.026    0.591
# 4                 Netherlands     5  7.488  1.396   1.522   0.999    0.557
# ..                        ...   ...    ...    ...     ...     ...      ...
# 151                    Rwanda   152  3.334  0.359   0.711   0.614    0.555
# 152                  Tanzania   153  3.231  0.476   0.885   0.499    0.417
# 153               Afghanistan   154  3.203  0.350   0.517   0.361    0.000
# 154  Central African Republic   155  3.083  0.026   0.000   0.105    0.225
# 155               South Sudan   156  2.853  0.306   0.575   0.295    0.010
#
#      Generosity  Corruption
# 0         0.153       0.393
# ...

# %%
rep_2019['Year']=2019

# %%
rep_2015 = rep_2015.drop(columns = ['Region','Standard Error','Dystopia Residual'])

# %%
rep_2015
# Out:
#          Country  Rank  Score      GDP   Family   Health  Freedom  Generosity  \
# 0    Switzerland     1  7.587  1.39651  1.34951  0.94143  0.66557     0.29678
# 1        Iceland     2  7.561  1.30232  1.40223  0.94784  0.62877     0.43630
# 2        Denmark     3  7.527  1.32548  1.36058  0.87464  0.64938     0.34139
# 3         Norway     4  7.522  1.45900  1.33095  0.88521  0.66973     0.34699
# 4         Canada     5  7.427  1.32629  1.32261  0.90563  0.63297     0.45811
# ..           ...   ...    ...      ...      ...      ...      ...         ...
# 153       Rwanda   154  3.465  0.22208  0.77370  0.42864  0.59201     0.22628
# 154        Benin   155  3.340  0.28665  0.35386  0.31910  0.48450     0.18260
# 155        Syria   156  3.006  0.66320  0.47489  0.72193  0.15684     0.47179
# 156      Burundi   157  2.905  0.01530  0.41587  0.22396  0.11850     0.19727
# 157         Togo   158  2.839  0.20868  0.13995  0.28443  0.36453     0.16681
#
#      Corruption  Year
# ...

# %%
rep_2016 = rep_2016.drop(columns=['Region','Upper Confidence Interval', 'Lower Confidence Interval','Standard Error', 'Dystopia Residual'])

# %%
rep_2016
# Out:
#          Country  Rank  Score      GDP   Family   Health  Freedom  Generosity  \
# 0        Denmark     1  7.526  1.44178  1.16374  0.79504  0.57941     0.36171
# 1    Switzerland     2  7.509  1.52733  1.14524  0.86303  0.58557     0.28083
# 2        Iceland     3  7.501  1.42666  1.18326  0.86733  0.56624     0.47678
# 3         Norway     4  7.498  1.57744  1.12690  0.79579  0.59609     0.37895
# 4        Finland     5  7.413  1.40598  1.13464  0.81091  0.57104     0.25492
# ..           ...   ...    ...      ...      ...      ...      ...         ...
# 152        Benin   153  3.484  0.39499  0.10419  0.21028  0.39747     0.20180
# 153  Afghanistan   154  3.360  0.38227  0.11037  0.17344  0.16430     0.31268
# 154         Togo   155  3.303  0.28123  0.00000  0.24811  0.34678     0.17517
# 155        Syria   156  3.069  0.74719  0.14866  0.62994  0.06912     0.48397
# 156      Burundi   157  2.905  0.06831  0.23442  0.15747  0.04320     0.20290
#
#      Corruption  Year
# ...

# %%
rep_2017=rep_2017.drop(columns=['Whisker.high','Whisker.low', 'Standard Error', 'Dystopia.Residual'])

# %%
rep_2017
# Out:
#                       Country  Rank  Score       GDP    Family    Health  \
# 0                      Norway     1  7.537  1.616463  1.533524  0.796667
# 1                     Denmark     2  7.522  1.482383  1.551122  0.792566
# 2                     Iceland     3  7.504  1.480633  1.610574  0.833552
# 3                 Switzerland     4  7.494  1.564980  1.516912  0.858131
# 4                     Finland     5  7.469  1.443572  1.540247  0.809158
# ..                        ...   ...    ...       ...       ...       ...
# 150                    Rwanda   151  3.471  0.368746  0.945707  0.326425
# 151                     Syria   152  3.462  0.777153  0.396103  0.500533
# 152                  Tanzania   153  3.349  0.511136  1.041990  0.364509
# 153                   Burundi   154  2.905  0.091623  0.629794  0.151611
# 154  Central African Republic   155  2.693  0.000000  0.000000  0.018773
#
#       Freedom  Generosity  Corruption  Year
# 0    0.635423    0.362012    0.315964  2017
# ...

# %%
rep_2018.columns
# Out:
# Index(['Country', 'Rank', 'Score', 'GDP', 'Family', 'Health', 'Freedom ',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
rep_2018.rename(columns = {'Freedom ':'Freedom'}, inplace = True)

# %% [markdown]
# Creating new dataframe by merging data from all the years.

# %%
col = ['Country', 'Rank', 'Score', 'GDP', 'Family', 'Health', 'Freedom', 'Generosity', 'Corruption', 'Year']
rep = pd.concat([rep_2015[col], rep_2016[col], rep_2017[col], rep_2018[col], rep_2019[col]], ignore_index = True)

# %%
rep
# Out:
#                       Country  Rank  Score      GDP   Family   Health  \
# 0                 Switzerland     1  7.587  1.39651  1.34951  0.94143
# 1                     Iceland     2  7.561  1.30232  1.40223  0.94784
# 2                     Denmark     3  7.527  1.32548  1.36058  0.87464
# 3                      Norway     4  7.522  1.45900  1.33095  0.88521
# 4                      Canada     5  7.427  1.32629  1.32261  0.90563
# ..                        ...   ...    ...      ...      ...      ...
# 777                    Rwanda   152  3.334  0.35900  0.71100  0.61400
# 778                  Tanzania   153  3.231  0.47600  0.88500  0.49900
# 779               Afghanistan   154  3.203  0.35000  0.51700  0.36100
# 780  Central African Republic   155  3.083  0.02600  0.00000  0.10500
# 781               South Sudan   156  2.853  0.30600  0.57500  0.29500
#
#      Freedom  Generosity  Corruption  Year
# 0    0.66557     0.29678     0.41978  2015
# ...

# %%
rep.isna().sum()
# Out:
# Country       0
# Rank          0
# Score         0
# GDP           0
# Family        0
# Health        0
# Freedom       0
# Generosity    0
# Corruption    1
# Year          0
# dtype: int64

# %%
rep.rename(columns = {'Rank':'H_Rank'}, inplace = True)

# %%
rep.to_csv('WHR15-19.csv', index = False)

# %%
rep.shape
# Out:
# (782, 10)

# %%
wh = pd.read_csv('C:\\Users\\sukra\\Projects2026\\WHR15-19.csv')

# %%
wh
# Out:
#                       Country  H_Rank  Score      GDP   Family   Health  \
# 0                 Switzerland       1  7.587  1.39651  1.34951  0.94143
# 1                     Iceland       2  7.561  1.30232  1.40223  0.94784
# 2                     Denmark       3  7.527  1.32548  1.36058  0.87464
# 3                      Norway       4  7.522  1.45900  1.33095  0.88521
# 4                      Canada       5  7.427  1.32629  1.32261  0.90563
# ..                        ...     ...    ...      ...      ...      ...
# 777                    Rwanda     152  3.334  0.35900  0.71100  0.61400
# 778                  Tanzania     153  3.231  0.47600  0.88500  0.49900
# 779               Afghanistan     154  3.203  0.35000  0.51700  0.36100
# 780  Central African Republic     155  3.083  0.02600  0.00000  0.10500
# 781               South Sudan     156  2.853  0.30600  0.57500  0.29500
#
#      Freedom  Generosity  Corruption  Year
# 0    0.66557     0.29678     0.41978  2015
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import mysql.connector
import os

# List of CSV files and their corresponding table names
csv_files = [
    ('WHR15-19.csv', 'Report'),    
]

# Connect to the MySQL database
conn = mysql.connector.connect(
    port = '3307',
    host='localhost',
    user='root',
    password='Chunmun@1905',
    database='WHR'
)
cursor = conn.cursor()

# Folder containing the CSV files
folder_path = 'C:\\Users\\sukra\\Projects2026'

def get_sql_type(dtype):
    if pd.api.types.is_integer_dtype(dtype):
        return 'INT'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'DATETIME'
    else:
        return 'TEXT'

for csv_file, table_name in csv_files:
    file_path = os.path.join(folder_path, csv_file)
    
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Replace NaN with None to handle SQL NULL
    df = df.where(pd.notnull(df), None)
    
    # Debugging: Check for NaN values
    print(f"Processing {csv_file}")
    print(f"NaN values before replacement:\n{df.isnull().sum()}\n")

    # Clean column names
    df.columns = [col.replace(' ', '_').replace('-', '_').replace('.', '_') for col in df.columns]

    # Generate the CREATE TABLE statement with appropriate data types
    columns = ', '.join([f'`{col}` {get_sql_type(df[col].dtype)}' for col in df.columns])
    create_table_query = f'CREATE TABLE IF NOT EXISTS `{table_name}` ({columns})'
    cursor.execute(create_table_query)

    # Insert DataFrame data into the MySQL table
    for _, row in df.iterrows():
        # Convert row to tuple and handle NaN/None explicitly
        values = tuple(None if pd.isna(x) else x for x in row)
        sql = f"INSERT INTO `{table_name}` ({', '.join(['`' + col + '`' for col in df.columns])}) VALUES ({', '.join(['%s'] * len(row))})"
        cursor.execute(sql, values)

    # Commit the transaction for the current CSV file
    conn.commit()

# Close the connection
conn.close()
# Out:
# Processing WHR15-19.csv
# NaN values before replacement:
# Country       0
# H_Rank        0
# Score         0
# GDP           0
# Family        0
# Health        0
# Freedom       0
# Generosity    0
# Corruption    1
# Year          0
# dtype: int64

# %%
db = mysql.connector.connect(port = '3307', host='localhost', username='root',password='Chunmun@1905',database='WHR')
cur = db.cursor()

# %%
query = """select country from report where h_rank=1"""
cur.execute(query)
data = cur.fetchall()
data
# Out:
# [('Switzerland',), ('Denmark',), ('Norway',), ('Finland',), ('Finland',)]

# %%
query = """select country, score, year from report where h_rank = 1"""
cur.execute(query)
data = cur.fetchall()
data
# Out:
# [('Switzerland', 7.587, 2015),
#  ('Denmark', 7.526, 2016),
#  ('Norway', 7.537, 2017),
#  ('Finland', 7.632, 2018),
#  ('Finland', 7.769, 2019)]

# %%
df = pd.DataFrame(data, columns = ['Country','Score','Year'])
df
# Out:
#        Country  Score  Year
# 0  Switzerland  7.587  2015
# 1      Denmark  7.526  2016
# 2       Norway  7.537  2017
# 3      Finland  7.632  2018
# 4      Finland  7.769  2019

# %%
plt.figure(figsize = (8,5))
plt.hist(rep.Score, bins = 100)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Most common happiness range is 5 to 6.

# %%
rep
# Out:
#                       Country  H_Rank  Score      GDP   Family   Health  \
# 0                 Switzerland       1  7.587  1.39651  1.34951  0.94143
# 1                     Iceland       2  7.561  1.30232  1.40223  0.94784
# 2                     Denmark       3  7.527  1.32548  1.36058  0.87464
# 3                      Norway       4  7.522  1.45900  1.33095  0.88521
# 4                      Canada       5  7.427  1.32629  1.32261  0.90563
# ..                        ...     ...    ...      ...      ...      ...
# 777                    Rwanda     152  3.334  0.35900  0.71100  0.61400
# 778                  Tanzania     153  3.231  0.47600  0.88500  0.49900
# 779               Afghanistan     154  3.203  0.35000  0.51700  0.36100
# 780  Central African Republic     155  3.083  0.02600  0.00000  0.10500
# 781               South Sudan     156  2.853  0.30600  0.57500  0.29500
#
#      Freedom  Generosity  Corruption  Year
# 0    0.66557     0.29678     0.41978  2015
# ...

# %%
rep.head(20)
# Out:
#                  Country  H_Rank  Score      GDP   Family   Health  Freedom  \
# 0            Switzerland       1  7.587  1.39651  1.34951  0.94143  0.66557
# 1                Iceland       2  7.561  1.30232  1.40223  0.94784  0.62877
# 2                Denmark       3  7.527  1.32548  1.36058  0.87464  0.64938
# 3                 Norway       4  7.522  1.45900  1.33095  0.88521  0.66973
# 4                 Canada       5  7.427  1.32629  1.32261  0.90563  0.63297
# 5                Finland       6  7.406  1.29025  1.31826  0.88911  0.64169
# 6            Netherlands       7  7.378  1.32944  1.28017  0.89284  0.61576
# 7                 Sweden       8  7.364  1.33171  1.28907  0.91087  0.65980
# 8            New Zealand       9  7.286  1.25018  1.31967  0.90837  0.63938
# 9              Australia      10  7.284  1.33358  1.30923  0.93156  0.65124
# 10                Israel      11  7.278  1.22857  1.22393  0.91387  0.41319
# ...

# %%
query = """select * from report where year = 2015"""
cur.execute(query)
data = cur.fetchall()
data
# Out:
# [('Switzerland',
#   1,
#   7.587,
#   1.39651,
#   1.34951,
#   0.94143,
#   0.66557,
#   0.29678,
#   0.41978,
#   2015),
#  ('Iceland',
#   2,
#   7.561,
#   1.30232,
#   1.40223,
#   0.94784,
#   0.62877,
#   0.4363,
#   0.14145,
#   2015),
#  ('Denmark',
#   3,
#   7.527,
#   1.32548,
#   1.36058,
#   0.87464,
#   0.64938,
#   0.34139,
#   0.48357,
#   2015),
#  ('Norway',
#   4,
#   7.522,
#   1.459,
#   1.33095,
#   0.88521,
#   0.66973,
#   0.34699,
#   0.36503,
#   2015),
#  ('Canada',
#   5,
#   7.427,
#   1.32629,
#   1.32261,
#   0.90563,
#   0.63297,
#   0.45811,
#   0.32957,
#   2015),
#  ('Finland',
#   6,
#   7.406,
#   1.29025,
#   1.31826,
#   0.88911,
#   0.64169,
#   0.23351,
#   0.41372,
#   2015),
#  ('Netherlands',
#   7,
#   7.378,
#   1.32944,
#   1.28017,
#   0.89284,
#   0.61576,
#   0.4761,
#   0.31814,
#   2015),
#  ('Sweden',
#   8,
#   7.364,
#   1.33171,
#   1.28907,
#   0.91087,
#   0.6598,
#   0.36262,
#   0.43844,
#   2015),
#  ('New Zealand',
# ...

# %%
query = """select * from report where score between 5 and 6"""
cur.execute(query)
data = cur.fetchall()
data
# Out:
# [('Slovakia',
#   45,
#   5.995,
#   1.16891,
#   1.26999,
#   0.78902,
#   0.31751,
#   0.16893,
#   0.03431,
#   2015),
#  ('Japan',
#   46,
#   5.987,
#   1.27074,
#   1.25712,
#   0.99111,
#   0.49615,
#   0.10705,
#   0.1806,
#   2015),
#  ('South Korea',
#   47,
#   5.984,
#   1.24461,
#   0.95774,
#   0.96538,
#   0.33208,
#   0.18557,
#   0.07857,
#   2015),
#  ('Ecuador',
#   48,
#   5.975,
#   0.86402,
#   0.99903,
#   0.79075,
#   0.48574,
#   0.11541,
#   0.1809,
#   2015),
#  ('Bahrain',
#   49,
#   5.96,
#   1.32376,
#   1.21624,
#   0.74716,
#   0.45492,
#   0.17362,
#   0.306,
#   2015),
#  ('Italy',
#   50,
#   5.948,
#   1.25114,
#   1.19777,
#   0.95446,
#   0.26236,
#   0.22823,
#   0.02901,
#   2015),
#  ('Bolivia',
#   51,
#   5.89,
#   0.68133,
#   0.97841,
#   0.5392,
#   0.57414,
#   0.20536,
#   0.088,
#   2015),
#  ('Moldova',
#   52,
#   5.889,
#   0.59448,
#   1.01528,
#   0.61826,
#   0.32818,
#   0.20951,
#   0.01615,
#   2015),
#  ('Paraguay',
#   53,
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                0   1      2        3        4        5        6        7  \
# 0       Slovakia  45  5.995  1.16891  1.26999  0.78902  0.31751  0.16893
# 1          Japan  46  5.987  1.27074  1.25712  0.99111  0.49615  0.10705
# 2    South Korea  47  5.984  1.24461  0.95774  0.96538  0.33208  0.18557
# 3        Ecuador  48  5.975  0.86402  0.99903  0.79075  0.48574  0.11541
# 4        Bahrain  49  5.960  1.32376  1.21624  0.74716  0.45492  0.17362
# ..           ...  ..    ...      ...      ...      ...      ...      ...
# 245        China  93  5.191  1.02900  1.12500  0.89300  0.52100  0.05800
# 246      Vietnam  94  5.175  0.74100  1.34600  0.85100  0.54300  0.14700
# 247       Bhutan  95  5.082  0.81300  1.32100  0.60400  0.45700  0.37000
# 248     Cameroon  96  5.044  0.54900  0.91000  0.33100  0.38100  0.18700
# 249     Bulgaria  97  5.011  1.09200  1.51300  0.81500  0.31100  0.08100
#
#            8     9
# 0    0.03431  2015
# 1    0.18060  2015
# 2    0.07857  2015
# ...

# %%
rep.shape
# Out:
# (782, 10)

# %% [markdown]
# 250 out of 782 rows, i.e., almost 32% score is in the range of 5 to 6.

# %%
query = """select * from report where score between 7 and 8"""
cur.execute(query)
data = cur.fetchall()
data
# Out:
# [('Switzerland',
#   1,
#   7.587,
#   1.39651,
#   1.34951,
#   0.94143,
#   0.66557,
#   0.29678,
#   0.41978,
#   2015),
#  ('Iceland',
#   2,
#   7.561,
#   1.30232,
#   1.40223,
#   0.94784,
#   0.62877,
#   0.4363,
#   0.14145,
#   2015),
#  ('Denmark',
#   3,
#   7.527,
#   1.32548,
#   1.36058,
#   0.87464,
#   0.64938,
#   0.34139,
#   0.48357,
#   2015),
#  ('Norway',
#   4,
#   7.522,
#   1.459,
#   1.33095,
#   0.88521,
#   0.66973,
#   0.34699,
#   0.36503,
#   2015),
#  ('Canada',
#   5,
#   7.427,
#   1.32629,
#   1.32261,
#   0.90563,
#   0.63297,
#   0.45811,
#   0.32957,
#   2015),
#  ('Finland',
#   6,
#   7.406,
#   1.29025,
#   1.31826,
#   0.88911,
#   0.64169,
#   0.23351,
#   0.41372,
#   2015),
#  ('Netherlands',
#   7,
#   7.378,
#   1.32944,
#   1.28017,
#   0.89284,
#   0.61576,
#   0.4761,
#   0.31814,
#   2015),
#  ('Sweden',
#   8,
#   7.364,
#   1.33171,
#   1.28907,
#   0.91087,
#   0.6598,
#   0.36262,
#   0.43844,
#   2015),
#  ('New Zealand',
# ...

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                  0   1      2        3        4        5        6        7  \
# 0      Switzerland   1  7.587  1.39651  1.34951  0.94143  0.66557  0.29678
# 1          Iceland   2  7.561  1.30232  1.40223  0.94784  0.62877  0.43630
# 2          Denmark   3  7.527  1.32548  1.36058  0.87464  0.64938  0.34139
# 3           Norway   4  7.522  1.45900  1.33095  0.88521  0.66973  0.34699
# 4           Canada   5  7.427  1.32629  1.32261  0.90563  0.63297  0.45811
# ..             ...  ..    ...      ...      ...      ...      ...      ...
# 67      Costa Rica  12  7.167  1.03400  1.44100  0.96300  0.55800  0.14400
# 68          Israel  13  7.139  1.27600  1.45500  1.02900  0.37100  0.26100
# 69      Luxembourg  14  7.090  1.60900  1.47900  1.01200  0.52600  0.19400
# 70  United Kingdom  15  7.054  1.33300  1.53800  0.99600  0.45000  0.34800
# 71         Ireland  16  7.021  1.49900  1.55300  0.99900  0.51600  0.29800
#
#           8     9
# 0   0.41978  2015
# 1   0.14145  2015
# ...

# %% [markdown]
# 9.89% of total score is above 7.

# %%
yearly_avg = rep.groupby('Year')['Score'].mean()

plt.figure(figsize=(8, 5))
plt.plot(yearly_avg.index, yearly_avg.values, marker='o')
plt.title('Average global happiness score (2015–2019)')
plt.xlabel('Year')
plt.ylabel('Average happiness score')
plt.show()

# %% [markdown]
# There is a sharp decline in happiness score in the year 2017.

# %%
rep_2017.head(10)
# Out:
#        Country  Rank  Score       GDP    Family    Health   Freedom  \
# 0       Norway     1  7.537  1.616463  1.533524  0.796667  0.635423
# 1      Denmark     2  7.522  1.482383  1.551122  0.792566  0.626007
# 2      Iceland     3  7.504  1.480633  1.610574  0.833552  0.627163
# 3  Switzerland     4  7.494  1.564980  1.516912  0.858131  0.620071
# 4      Finland     5  7.469  1.443572  1.540247  0.809158  0.617951
# 5  Netherlands     6  7.377  1.503945  1.428939  0.810696  0.585384
# 6       Canada     7  7.316  1.479204  1.481349  0.834558  0.611101
# 7  New Zealand     8  7.314  1.405706  1.548195  0.816760  0.614062
# 8       Sweden     9  7.284  1.494387  1.478162  0.830875  0.612924
# 9    Australia    10  7.284  1.484415  1.510042  0.843887  0.601607
#
#    Generosity  Corruption  Year
# 0    0.362012    0.315964  2017
# 1    0.355280    0.400770  2017
# 2    0.475540    0.153527  2017
# 3    0.290549    0.367007  2017
# 4    0.245483    0.382612  2017
# ...

# %%
rep_2016.head(10)
# Out:
#        Country  Rank  Score      GDP   Family   Health  Freedom  Generosity  \
# 0      Denmark     1  7.526  1.44178  1.16374  0.79504  0.57941     0.36171
# 1  Switzerland     2  7.509  1.52733  1.14524  0.86303  0.58557     0.28083
# 2      Iceland     3  7.501  1.42666  1.18326  0.86733  0.56624     0.47678
# 3       Norway     4  7.498  1.57744  1.12690  0.79579  0.59609     0.37895
# 4      Finland     5  7.413  1.40598  1.13464  0.81091  0.57104     0.25492
# 5       Canada     6  7.404  1.44015  1.09610  0.82760  0.57370     0.44834
# 6  Netherlands     7  7.339  1.46468  1.02912  0.81231  0.55211     0.47416
# 7  New Zealand     8  7.334  1.36066  1.17278  0.83096  0.58147     0.49401
# 8    Australia     9  7.313  1.44443  1.10476  0.85120  0.56837     0.47407
# 9       Sweden    10  7.291  1.45181  1.08764  0.83121  0.58218     0.38254
#
#    Corruption  Year
# 0     0.44453  2016
# 1     0.41203  2016
# 2     0.14975  2016
# 3     0.35776  2016
# 4     0.41004  2016
# ...

# %%
df = pd.concat([rep_2016.head(10),rep_2017.head(10)], ignore_index=True)
df
# Out:
#         Country  Rank  Score       GDP    Family    Health   Freedom  \
# 0       Denmark     1  7.526  1.441780  1.163740  0.795040  0.579410
# 1   Switzerland     2  7.509  1.527330  1.145240  0.863030  0.585570
# 2       Iceland     3  7.501  1.426660  1.183260  0.867330  0.566240
# 3        Norway     4  7.498  1.577440  1.126900  0.795790  0.596090
# 4       Finland     5  7.413  1.405980  1.134640  0.810910  0.571040
# 5        Canada     6  7.404  1.440150  1.096100  0.827600  0.573700
# 6   Netherlands     7  7.339  1.464680  1.029120  0.812310  0.552110
# 7   New Zealand     8  7.334  1.360660  1.172780  0.830960  0.581470
# 8     Australia     9  7.313  1.444430  1.104760  0.851200  0.568370
# 9        Sweden    10  7.291  1.451810  1.087640  0.831210  0.582180
# 10       Norway     1  7.537  1.616463  1.533524  0.796667  0.635423
# 11      Denmark     2  7.522  1.482383  1.551122  0.792566  0.626007
# 12      Iceland     3  7.504  1.480633  1.610574  0.833552  0.627163
# ...

# %%
rep.columns
# Out:
# Index(['Country', 'H_Rank', 'Score', 'GDP', 'Family', 'Health', 'Freedom',
#        'Generosity', 'Corruption', 'Year'],
#       dtype='object')

# %%
cols = ['Score', 'GDP', 'Family', 'Health', 'Freedom','Generosity', 'Corruption']

for col in cols:
    a = sns.lineplot(x = df.Rank, y=df[col], hue = df.Year)
    plt.show()

# %%
query = """select * from report where year in (2016,2017)"""
cur.execute(query)
data = cur.fetchall()
df=pd.DataFrame(data, columns = ['Country', 'H_Rank', 'Score', 'GDP', 'Family', 'Health', 'Freedom','Generosity', 'Corruption', 'Year'])
df
# Out:
#                       Country  H_Rank  Score       GDP    Family    Health  \
# 0                     Denmark       1  7.526  1.441780  1.163740  0.795040
# 1                 Switzerland       2  7.509  1.527330  1.145240  0.863030
# 2                     Iceland       3  7.501  1.426660  1.183260  0.867330
# 3                      Norway       4  7.498  1.577440  1.126900  0.795790
# 4                     Finland       5  7.413  1.405980  1.134640  0.810910
# ..                        ...     ...    ...       ...       ...       ...
# 307                    Rwanda     151  3.471  0.368746  0.945707  0.326425
# 308                     Syria     152  3.462  0.777153  0.396103  0.500533
# 309                  Tanzania     153  3.349  0.511136  1.041990  0.364509
# 310                   Burundi     154  2.905  0.091623  0.629794  0.151611
# 311  Central African Republic     155  2.693  0.000000  0.000000  0.018773
#
#       Freedom  Generosity  Corruption  Year
# ...

# %%
cols = ['Score', 'GDP', 'Family', 'Health', 'Freedom','Generosity', 'Corruption']

for col in cols:
    a = sns.lineplot(x = df.H_Rank, y=df[col], hue = df.Year)
    plt.show()

# %%
set_2016 = set(rep_2016.Country.head(10))
set_2017 = set(rep_2017.Country.head(10))

print("In 2016 top 10 but not 2017:", set_2016 - set_2017)
print("In 2017 top 10 but not 2015:", set_2017 - set_2016)
# Out:
# In 2016 top 10 but not 2017: set()
# In 2017 top 10 but not 2015: set()

# %%
x = rep_2016.Rank.head(10)
y1 = rep_2016.Score.head(10)
y2 = rep_2017.Score.head(10)

# %%
comparison = pd.DataFrame({
    'Rank': x,
    'Country_2016': rep_2016.Country.head(10).values,
    'Score_2016': y1,
    'Country_2017': rep_2017.Country.head(10).values,
    'Score_2017': y2,
    'Difference': y1.values - y2.values
})
comparison
# Out:
#    Rank Country_2016  Score_2016 Country_2017  Score_2017  Difference
# 0     1      Denmark       7.526       Norway       7.537      -0.011
# 1     2  Switzerland       7.509      Denmark       7.522      -0.013
# 2     3      Iceland       7.501      Iceland       7.504      -0.003
# 3     4       Norway       7.498  Switzerland       7.494       0.004
# 4     5      Finland       7.413      Finland       7.469      -0.056
# 5     6       Canada       7.404  Netherlands       7.377       0.027
# 6     7  Netherlands       7.339       Canada       7.316       0.023
# 7     8  New Zealand       7.334  New Zealand       7.314       0.020
# 8     9    Australia       7.313       Sweden       7.284       0.029
# 9    10       Sweden       7.291    Australia       7.284       0.007

# %%
rep_2017.describe()
# Out:
#              Rank       Score         GDP      Family      Health     Freedom  \
# count  155.000000  155.000000  155.000000  155.000000  155.000000  155.000000
# mean    78.000000    5.354019    0.984718    1.188898    0.551341    0.408786
# std     44.888751    1.131230    0.420793    0.287263    0.237073    0.149997
# min      1.000000    2.693000    0.000000    0.000000    0.000000    0.000000
# 25%     39.500000    4.505500    0.663371    1.042635    0.369866    0.303677
# 50%     78.000000    5.279000    1.064578    1.253918    0.606042    0.437454
# 75%    116.500000    6.101500    1.318027    1.414316    0.723008    0.516561
# max    155.000000    7.537000    1.870766    1.610574    0.949492    0.658249
#
#        Generosity  Corruption    Year
# count  155.000000  155.000000   155.0
# mean     0.246883    0.123120  2017.0
# std      0.134780    0.101661     0.0
# min      0.000000    0.000000  2017.0
# 25%      0.154106    0.057271  2017.0
# ...

# %%
query = """select * from report where (GDP=0 or Family=0 or health=0 or freedom=0 or generosity=0 or corruption=0)"""
cur.execute(query)
data = cur.fetchall()
df = pd.DataFrame(data, columns = ['Country', 'H_Rank', 'Score', 'GDP', 'Family', 'Health', 'Freedom','Generosity', 'Corruption', 'Year'])
df
# Out:
#                      Country  H_Rank  Score       GDP   Family    Health  \
# 0                  Indonesia      74  5.399  0.828270  1.08708  0.637930
# 1                     Greece     102  4.857  1.154060  0.92933  0.882130
# 2                       Iraq     112  4.677  0.985490  0.81889  0.602370
# 3           Congo (Kinshasa)     120  4.517  0.000000  1.00120  0.098060
# 4               Sierra Leone     123  4.507  0.330240  0.95571  0.000000
# 5   Central African Republic     148  3.678  0.078500  0.00000  0.066990
# 6                    Somalia      76  5.440  0.000000  0.33613  0.114660
# 7     Bosnia and Herzegovina      87  5.163  0.933830  0.64367  0.707660
# 8                     Greece      99  5.033  1.248860  0.75473  0.800290
# 9               Sierra Leone     111  4.635  0.364850  0.62800  0.000000
# 10                     Sudan     133  4.139  0.630690  0.81928  0.297590
# 11                      Togo     155  3.303  0.281230  0.00000  0.248110
# ...

# %%
cols = ['GDP','Family','Health','Freedom','Generosity','Corruption']
for col in cols:
    zero_rows = df[df[col] == 0]
    print(zero_rows)
# Out:
#                      Country  H_Rank  Score  GDP   Family    Health   Freedom  \
# 3           Congo (Kinshasa)     120  4.517  0.0  1.00120  0.098060  0.226050
# 6                    Somalia      76  5.440  0.0  0.33613  0.114660  0.567780
# 16  Central African Republic     155  2.693  0.0  0.00000  0.018773  0.270842
# 20                   Somalia      98  4.982  0.0  0.71200  0.115000  0.674000
# 26                   Somalia     112  4.668  0.0  0.69800  0.268000  0.559000
#
#     Generosity  Corruption  Year
# 3     0.248340    0.076250  2015
# 6     0.272250    0.311800  2016
# 16    0.280876    0.056565  2017
# 20    0.238000    0.282000  2018
# 26    0.243000    0.270000  2019
#                      Country  H_Rank  Score      GDP  Family    Health  \
# 5   Central African Republic     148  3.678  0.07850     0.0  0.066990
# 11                      Togo     155  3.303  0.28123     0.0  0.248110
# 16  Central African Republic     155  2.693  0.00000     0.0  0.018773
# ...

# %%
plt.figure(figsize = (8,5))
sns.heatmap(rep[['Score','GDP','Family','Health','Freedom','Generosity','Corruption']].corr(),annot = True, cmap='coolwarm')
plt.show()

# %% [markdown]
# GDP, family support and health are the factors affecting happiness score the most.

# %%
avg = rep.groupby('Country')['Score'].mean()
top_10 = avg.nlargest(10).sort_values()
top_10
# Out:
# Country
# Australia      7.2762
# New Zealand    7.3130
# Sweden         7.3192
# Canada         7.3506
# Netherlands    7.4046
# Iceland        7.5110
# Switzerland    7.5114
# Finland        7.5378
# Norway         7.5410
# Denmark        7.5460
# Name: Score, dtype: float64

# %%
plt.figure(figsize = (10,6))
ax = top_10.plot(kind='barh')
ax.bar_label(ax.containers[0])
plt.show()

# %%
bottom_10 = avg.nsmallest(10)
bottom_10
# Out:
# Country
# Burundi                     3.07900
# Central African Republic    3.13425
# Syria                       3.29220
# South Sudan                 3.38250
# Rwanda                      3.43860
# Tanzania                    3.46600
# Afghanistan                 3.51280
# Togo                        3.54420
# Yemen                       3.62580
# Madagascar                  3.74540
# Name: Score, dtype: float64

# %%
plt.figure(figsize = (10,6))
ax = bottom_10.plot(kind='barh')
ax.bar_label(ax.containers[0])
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.scatterplot(x = rep.GDP, y = rep.Score, hue = rep.Year, palette = 'muted')
plt.show()

# %%
score_2015 = rep[rep['Year'] == 2015].set_index('Country')['Score']
score_2019 = rep[rep['Year'] == 2019].set_index('Country')['Score']

change = score_2019 - score_2015
change = change.dropna().sort_values()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

change.tail(10).plot(kind='barh', ax=axes[0])
axes[0].set_title('Most improved countries')
axes[0].set_xlabel('Change in score')

change.head(10).plot(kind='barh', ax=axes[1])
axes[1].set_title('Most declined countries')
axes[1].set_xlabel('Change in score')

plt.tight_layout()
plt.show()

# %%
factors = ['Score','GDP','Family','Health','Freedom']
sns.pairplot(rep[factors], diag_kind='kde')
plt.show()

# %%
country_data = rep[rep['Country']=='India'].groupby('Year')[['GDP','Family','Health','Freedom','Generosity']].mean()

country_data.plot(kind='bar', stacked=True, figsize=(10,6))
plt.title('Happiness factor breakdown')
plt.ylabel('Contribution to score')
plt.xlabel('Year')
plt.legend(title='Factor')
plt.show()
